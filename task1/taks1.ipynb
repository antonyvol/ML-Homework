# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def poly(c, x):
    return c[0] + c[1]*x + c[2]*(x**2) + c[3]*(x**3) + c[4]*(x**4)
    

# sgd DOES WORK
def sgd(c, x, y, lr):
    nc = c
    m = len(x)
    for i in range(m):
        for j in range(5):
            nc[j] = c[j] + lr * (y[i] - poly(c, x[i])) * x[i] ** j
    return nc

# %%
n = 100

x = np.random.uniform(0.0, 1.0, n)
e = np.random.uniform(-0.3, 0.3, n)
y = np.sin(2*np.pi*x) + e

# %%
plt.figure(figsize=(10,5))
plt.scatter(x, y)

# %%
c = np.random.uniform(-0.5, 0.5, 5)
y_pred = np.array([poly(c, v) for v in x])

# %%
y_pred
# Out:
# array([-0.28471824, -0.24324373, -0.22783043, -0.25704056, -0.21779966,
#        -0.21424656, -0.23670453, -0.27566507, -0.24142374, -0.21112124,
#        -0.22222667, -0.23988056, -0.21040395, -0.21177101, -0.24635608,
#        -0.24042051, -0.21980118, -0.23810191, -0.21369399, -0.24535907,
#        -0.23298681, -0.21169602, -0.21103258, -0.27354468, -0.22825094,
#        -0.28169619, -0.22558895, -0.24610742, -0.23884813, -0.21890228,
#        -0.21738906, -0.21718365, -0.24648165, -0.22892854, -0.22831305,
#        -0.24360276, -0.22189609, -0.22359044, -0.24305536, -0.24443494,
#        -0.22115129, -0.23862531, -0.24309904, -0.24556405, -0.22498169,
#        -0.24252324, -0.22177309, -0.23403213, -0.23815057, -0.22070334,
#        -0.2515281 , -0.24496877, -0.27023188, -0.23927046, -0.22684098,
#        -0.22164382, -0.24655708, -0.22524864, -0.22485205, -0.22207378,
#        -0.23449273, -0.22040265, -0.21261894, -0.24581499, -0.21131943,
#        -0.24254269, -0.23087119, -0.2155816 , -0.24605047, -0.24277499,
#        -0.24553012, -0.24593333, -0.24407624, -0.2218921 , -0.28118631,
#        -0.22231953, -0.22351908, -0.21943032, -0.27656026, -0.21526943,
#        -0.22604083, -0.22932943, -0.2449545 , -0.25647413, -0.26077944,
#        -0.24215495, -0.23846874, -0.24630313, -0.22956305, -0.220991  ,
#        -0.23542649, -0.21787129, -0.24496411, -0.24599742, -0.21823994,
#        -0.22462815, -0.28334584, -0.24371437, -0.22821201, -0.21928336])

# %%
plt.figure(figsize=(10,5))
plt.scatter(x, y)
plt.scatter(x, y_pred)

# %%
lr = 0.1

for _ in range(1000):
    c = sgd(c, x, y, lr)
    
y_pred = np.array([poly(c, v) for v in x])

# %%
y_pred
# Out:
# array([ 0.2754378 , -1.07788199, -0.75235296,  0.63804439,  0.7848348 ,
#        -0.09020332, -1.00850636,  0.40493927, -1.07686829,  0.55970839,
#        -0.52802582, -1.0624713 ,  0.34486606,  0.11930841, -0.95105895,
#        -1.06860102, -0.41398618,  0.12776739, -0.04975229, -0.58094608,
#        -0.91692353,  0.60479311,  0.55098766,  0.43392828, -0.76725414,
