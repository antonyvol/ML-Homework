# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def poly(c, x):
    return c[0] + c[1]*x + c[2]*(x**2) + c[3]*(x**3) + c[4]*(x**4)
    

# sgd
def sgd(c, x, y, lr):
    nc = c
    for i in range(len(x)):
        for j in range(5):
            nc[j] = c[j] + lr * (y[i] - poly(c, x[i])) * x[i]
    return nc

# %%
n = 100

x = np.random.uniform(0.0, 1.0, n)
e = np.random.uniform(-0.3, 0.3, n)
y = np.sin(2*np.pi*x) + e

# %%
plt.figure(figsize=(10,5))
plt.scatter(x, y)

# %%
c = np.random.uniform(-0.5, 0.5, 5)
y_pred = np.array([poly(c, v) for v in x])

# %%
c
# Out:
# array([-0.00854218, -0.08103808, -0.31735824,  0.15844912,  0.11044923])

# %%
plt.figure(figsize=(10,5))
plt.scatter(x, y)
plt.scatter(x, y_pred)

# %%
lr = 0.01

for _ in range(100):
    c = sgd(c, x, y, lr)
    
y_pred = np.array([poly(c, v) for v in x])

# %%
c
# Out:
# array([-0.15077871, -0.18084039, -0.37420795,  0.13694553,  0.11614648])

# %%
plt.figure(figsize=(10,5))
plt.scatter(x, y)
plt.scatter(x, y_pred)
